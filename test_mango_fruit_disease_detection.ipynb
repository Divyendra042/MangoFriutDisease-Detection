# %% [markdown]
# # Predict with new data

# %% [markdown]
# ### Import all Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.image import imread
import tensorflow as tf
from keras.preprocessing import image

# %% [markdown]
# ### Load the model

# %%
import tensorflow as tf
import os

# Image dimensions
img_height = 180
img_width = 180

# ✅ Set your model path here
# If your model is in the same folder as app.py:
model_path = r'C:\Users\divye\Desktop\Mango_Disease_Detection_API-main\Mango_Fruit_Detection_Model.h5'

# If it's inside a subfolder like 'models', use this instead:
# model_path = r'C:\Users\divye\Desktop\Mango_Disease_Detection_API-main\models\Mango_Fruit_Detection_Model.h5'

# 🔍 Check if the model file exists before loading
if os.path.exists(model_path):
    model = tf.keras.models.load_model(model_path)
    print("✅ Model loaded successfully!")
else:
    print("❌ Model file not found!")
    print("Expected path:", model_path)
    print("Please check the filename and folder location.")

# %% [markdown]
# ### Declare class names

# %%
class_names = ['Alternaria', 'Anthracnose', 'Black_Mould_Rot', 'Healthy', 'Stem_and_Rot']
class_name = {1: 'Alternaria', 2: 'Anthracnose', 3: 'Black_Mould_Rot', 4: 'Healthy', 5: 'Stem_and_Rot'}

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("mango_dataset/Mango_fruit_dataset.csv")
df = df.replace('',np.nan)
df = df.dropna(axis="columns",how="any")
df
# Out:
#    Sn no      Disease Type                Severity       Location/Date  \
# 0       1       Alternaria  Mild, Moderate, Severe  [Location], [Date]
# 1       2      Anthracnose  Mild, Moderate, Severe  [Location], [Date]
# 2       3  Black mold root  Mild, Moderate, Severe  [Location], [Date]
# 3       4          Healthy                 Healthy  [Location], [Date]
# 4       5   Steam and root  Mild, Moderate, Severe  [Location], [Date]
#
#                                          Description  \
# 0  A fungal disease that causes dark brown or bla...
# 1  A fungal disease that causes dark brown to bla...
# 2  A fungal disease that causes black mold to gro...
# 3                               No signs of disease.
# 4  A fungal disease that causes the roots of mang...
#
#                                             Symptoms  \
# 0  Spots on leaves are circular to irregular in s...
# 1  Spots on leaves are circular to irregular in s...
# ...

# %% [markdown]
# ### Giving image as input

# %%
path = "mango_dataset/goodMango1.jpg"

# %% [markdown]
# ### image preprocessing

# %%
img = image.load_img(path,target_size=(img_height,img_width))
img = image.img_to_array(img)
img = np.expand_dims(img,axis=0)
# img = preprocess_input(img)



prediction = model.predict(img)

predicted_class = np.argmax(prediction)

print(f"Predicted class : {predicted_class}")
print(f"Predict Disease : {class_names[predicted_class]}")
df
Sn_no, Disease_Type, Severity, Location_Date ,Description ,Symptoms  ,Diagnosis ,Precautions = df.loc[predicted_class,:]
img = imread(path)
plt.imshow(img)
plt.axis('off')
plt.show()

print(f"\n\nDisease Type : {Disease_Type}\nSeverity : {Severity}\nDescription : {Description}\nSymptoms : {Symptoms}\nDiagnosis : {Diagnosis}\nPrecautions : {Precautions}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Predicted class : 3
# Predict Disease : Healthy
# Disease Type : Healthy
# Severity : Healthy
# Description : No signs of disease.
# Symptoms : Leaves are green and healthy, fruit is free of spots, and the tree is growing vigorously.
# Diagnosis : No diagnosis necessary.
# Precautions : Continue to monitor the tree for signs of disease.
